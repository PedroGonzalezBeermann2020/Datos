# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroGonzalezBeermann2020/Datos/blob/main/RTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x2=seq(2,8,0.1)
y2=dnorm(x2,5,1)

# %%
x=rnorm(10000,5,1)
hist(x,breaks=50,freq=FALSE,col="green",ylim=c(0,0.5))
lines(density(x),col="blue")
lines(x2,y2)
# Out:
# Plot with title “Histogram of x”
